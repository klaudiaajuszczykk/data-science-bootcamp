# %% [markdown]
# <a href="https://colab.research.google.com/github/klaudiaajuszczykk/data-science-bootcamp/blob/main/%C4%87wiczenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello colab")
# Out:
# hello colab
